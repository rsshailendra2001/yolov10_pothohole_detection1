# %%
# !nvidia-smi

# %%
import os
HOME = os.getcwd()
print(HOME)

# %%
# Pip install method (recommended)

# !pip install ultralytics

from IPython import display
display.clear_output()

import ultralytics
ultralytics.checks()

# %%
import os

# Original path
original_path = '/pothole dataset_yolov8_format/'
# New symbolic link path
short_path = '/dataset'

# Create a symbolic link
os.symlink(original_path, short_path)

print("Path shortened. You can now access the dataset with:", short_path)

# %%
# !yolo task=detect mode=train model=yolo11n.pt data=data.yaml epochs=325 imgsz=640 plots=True
# Out:
# Ultralytics 8.3.51 🚀 Python-3.10.12 torch-2.5.1+cu124 CUDA:0 (NVIDIA RTX A4000, 16102MiB)
# ...

# %%
# !yolo task=detect mode=train model=yolo11n.pt data=data.yaml epochs=325 imgsz=640 plots=True

# %%
# !yolo task=detect mode=train model=yolo11s.pt data=data.yaml epochs=325 imgsz=640 plots=True

# %%
# !yolo task=detect mode=train model=yolov10n.pt data=data.yaml epochs=325 imgsz=640 plots=True

# %%
# !yolo task=detect mode=train model=yolo11s.pt data=data.yaml epochs=500 imgsz=640 plots=True

# %%
# !yolo task=detect mode=train model=yolo11s.pt data=data.yaml epochs=325 imgsz=640 plots=True

# %%
# !yolo task=detect mode=train model=runs/detect/train11/weights/best.pt data=data.yaml epochs=260 imgsz=640 plots=True

# %%
# !yolo task=detect mode=train model=yolo11s.pt data=data.yaml epochs=260 imgsz=640 plots=True

# %%
# !yolo task=detect mode=train model=yolo11s.pt data=data.yaml epochs=225 imgsz=640 plots=True

# %%
# !yolo task=detect mode=train model=yolo11m.pt data=data.yaml epochs=225 imgsz=640 plots=True

# %%
# !yolo task=detect mode=train model=yolo11m.pt data=data.yaml epochs=100 imgsz=640 plots=True

# %%
# !yolo task=detect mode=train model=yolov10n.pt data=data.yaml epochs=100 imgsz=640 plots=True

# %%
# !yolo task=detect mode=train model=yolov10n.pt data=data.yaml epochs=200 imgsz=640 plots=True

# %%
# !yolo task=detect mode=train model=yolov10n.pt data=data.yaml epochs=300 imgsz=640 plots=True

# %%
# !yolo task=detect mode=train model=yolov10n.pt data=data.yaml epochs=325 imgsz=640 plots=True
# Out:
#      65/325      3.11G      2.755      2.166      2.627         30        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all       1808       4487      0.843      0.729      0.817      0.517
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      66/325      3.22G      2.742      2.167      2.644         72        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all       1808       4487      0.841      0.735      0.819      0.517
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      67/325      3.16G      2.718      2.148      2.613         28        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all       1808       4487      0.847      0.733       0.82      0.521
#
# ...

# %%
# !yolo task=detect mode=train model=yolo11s.pt data=data.yaml epochs=325 imgsz=640 plots=True
# Out:
# Ultralytics 8.3.51 🚀 Python-3.10.12 torch-2.5.1+cu124 CUDA:0 (NVIDIA RTX A4000, 16102MiB)
# ...

# %%
# !yolo task=detect mode=train model=yolo11l.pt data=data.yaml epochs=132 imgsz=640 plots=True
# Out:
# Ultralytics 8.3.51 🚀 Python-3.10.12 torch-2.5.1+cu124 CUDA:0 (NVIDIA RTX A4000, 16102MiB)
# ...

# %%
# !yolo task=detect mode=train model=yolov10n.pt data=data.yaml epochs=600 imgsz=640 plots=True

# %%
# !yolo task=detect mode=train model=runs/detect/train20/weights/best.pt data=data-Copy.yaml epochs=100 imgsz=640 plots=True

# %%
# !yolo task=detect mode=train model=runs/detect/train20/weights/best.pt data=data-Copy.yaml epochs=200 imgsz=640 plots=True

# %%
# !yolo task=detect mode=train model=yolov10s.pt data=data.yaml epochs=200 imgsz=640 plots=True

# %%
# !yolo task=detect mode=train model=yolov10s.pt data=data.yaml epochs=150 imgsz=640 plots=True

# %%
# !yolo task=detect mode=train model=yolov10l.pt data=data.yaml epochs=100 imgsz=640 plots=True

# %%
# !yolo task=detect mode=train model=yolov8n.pt data=data.yaml epochs=100 imgsz=640 plots=True

# %%
# !yolo task=detect mode=train model=yolov8n.pt data=data.yaml epochs=200 imgsz=640 plots=True

# %%
# !yolo task=detect mode=train model=yolov8n.pt data=data.yaml epochs=300 imgsz=640 plots=True

# %%
# !yolo task=detect mode=train model=yolov8n.pt data=data.yaml epochs=600 imgsz=640 plots=True

# %%
# !yolo task=detect mode=train model=yolov8s.pt data=data.yaml epochs=600 imgsz=640 plots=True

# %%
# Import necessary libraries
import os
import zipfile

# Function to zip a folder
def zip_folder(folder_path, zip_name):
    """
    Compress a folder into a zip file.

    Parameters:
    folder_path (str): Path to the folder to be zipped.
    zip_name (str): Name of the resulting zip file.
    """
    with zipfile.ZipFile(zip_name, 'w', zipfile.ZIP_DEFLATED) as zipf:
        for root, dirs, files in os.walk(folder_path):
            for file in files:
                file_path = os.path.join(root, file)
                # Add file to zip, keeping the relative path
                arcname = os.path.relpath(file_path, start=folder_path)
                zipf.write(file_path, arcname)
    print(f"Folder '{folder_path}' has been compressed into '{zip_name}'.")

# Define folder to zip and output zip file name
folder_to_zip = "runs/detect/train11"  # Change this to the folder path
zip_output_name = "yolov11l(132epoch)output.zip"         # Change this to your desired zip file name

# Call the function
zip_folder(folder_to_zip, zip_output_name)

# Verify if the zip file was created
if os.path.exists(zip_output_name):
    print(f"'{zip_output_name}' created successfully!")
else:
    print("Error: Zip file was not created.")
# Out:
# Folder 'runs/detect/train11' has been compressed into 'yolov11l(132epoch)output.zip'.
# 'yolov11l(132epoch)output.zip' created successfully!
